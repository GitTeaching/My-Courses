# %% [markdown]
# # Série TP 2 – Partie 2 - Fouille de Données – Association Rules - Apriori

# %% [markdown]
# ## Implementing Market Basket Analysis using mlxtend Package

# %% [markdown]
# Market Basket Analysis, also known as Association analysis, is a method for understanding client purchase trends based on historical data. In other words, Market Basket Analysis enables merchants to find links between the products that customers purchase.
#
# Learn more : https://www.thepythoncode.com/article/build-a-recommender-system-with-association-rule-mining-in-python

# %%
# !pip install --user mlxtend-0.21.0-py2.py3-none-any.whl

# %%
# Loading neccesary packages
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# ## Dataset 1 - Simple Example

# %%
dataset = [['Milk', 'Onion', 'Nutmeg', 'Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Beans', 'Ice cream', 'Eggs']]

# %%
# Convert the dataset into a formal table
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
dataframe = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# Print 5 first lignes of the dataset dataframe
dataframe.head()
# Out:
#    Apple  Beans   Corn   Dill   Eggs  Ice cream   Milk  Nutmeg  Onion  \
# 0  False   True  False  False   True      False   True    True   True
# 1  False   True  False   True   True      False  False    True   True
# 2   True   True  False  False   True      False   True   False  False
# 3  False   True   True  False  False      False   True   False  False
# 4  False   True   True  False   True       True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
dataframe.shape
# Out:
# (5, 11)

# %%
dataframe.columns
# Out:
# Index(['Apple', 'Beans', 'Corn', 'Dill', 'Eggs', 'Ice cream', 'Milk', 'Nutmeg',
#        'Onion', 'Unicorn', 'Yogurt'],
#       dtype='object')

# %%
# Applying Apriori algorithm 
freq_items = apriori(dataframe, min_support=0.6, use_colnames=True)

# %%
freq_items
# Out:
#     support              itemsets
# 0       1.0               (Beans)
# 1       0.8                (Eggs)
# 2       0.6                (Milk)
# 3       0.6               (Onion)
# 4       0.6              (Yogurt)
# 5       0.8         (Eggs, Beans)
# 6       0.6         (Milk, Beans)
# 7       0.6        (Onion, Beans)
# 8       0.6       (Yogurt, Beans)
# 9       0.6         (Eggs, Onion)
# 10      0.6  (Eggs, Onion, Beans)

# %%
# Filtering frequent itemsets based on their support
freq_items[freq_items['support'] >= 0.8]
# Out:
#    support       itemsets
# 0      1.0        (Beans)
# 1      0.8         (Eggs)
# 5      0.8  (Eggs, Beans)

# %% [markdown]
# - support(A->C) = support(A+C) [aka 'support'], range: [0, 1]
#
# - confidence(A->C) = support(A+C) / support(A), range: [0, 1]
#
# - lift(A->C) = confidence(A->C) / support(C), range: [0, inf]
#
# - leverage(A->C) = support(A->C) - support(A)*support(C),
# range: [-1, 1]
#
# - conviction = [1 - support(C)] / [1 - confidence(A->C)],
# range: [0, inf]

# %%
# Extracting association rules from the frequent itemsets
rules = association_rules(freq_items, metric="confidence", min_threshold=0.7)

# %%
rules.head()
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0      (Eggs)     (Beans)                 0.8                 1.0      0.8
# 1     (Beans)      (Eggs)                 1.0                 0.8      0.8
# 2      (Milk)     (Beans)                 0.6                 1.0      0.6
# 3     (Onion)     (Beans)                 0.6                 1.0      0.6
# 4    (Yogurt)     (Beans)                 0.6                 1.0      0.6
#
#    confidence  lift  leverage  conviction
# 0         1.0   1.0       0.0         inf
# 1         0.8   1.0       0.0         1.0
# 2         1.0   1.0       0.0         inf
# 3         1.0   1.0       0.0         inf
# 4         1.0   1.0       0.0         inf

# %%
rules[(rules['confidence'] > 0.75) & (rules['lift'] > 1.2)]
# Out:
#        antecedents    consequents  antecedent support  consequent support  \
# 6          (Onion)         (Eggs)                 0.6                 0.8
# 9   (Onion, Beans)         (Eggs)                 0.6                 0.8
# 11         (Onion)  (Eggs, Beans)                 0.6                 0.8
#
#     support  confidence  lift  leverage  conviction
# 6       0.6         1.0  1.25      0.12         inf
# 9       0.6         1.0  1.25      0.12         inf
# 11      0.6         1.0  1.25      0.12         inf

# %% [markdown]
# ## Dataset 2 - Online Retail Dataset

# %% [markdown]
# The dataset is a transnational data collection covering all transactions made by a UK-based and registered non-store internet retailer between 2010 and 2011. The dataset includes information on 500K clients across eight attributes.
#
# Learn more about the dataset and its analysis here: https://www.thepythoncode.com/article/build-a-recommender-system-with-association-rule-mining-in-python

# %% [markdown]
# ### Data Load and Preparation

# %%
# Loading data from CSV file
myretaildata = pd.read_csv('Online_Retail_Cleaned.csv')
# Out:
# C:\Users\LeE\AppData\Local\Temp\ipykernel_7116\2469686962.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   myretaildata = pd.read_csv('Online_Retail_Cleaned.csv')

# %%
# Data Cleaning - removes duplicate invoice
myretaildata.dropna(axis=0, subset=['InvoiceNo'], inplace=True) 
myretaildata.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
myretaildata['Country'].value_counts()
# Out:
# United Kingdom          487622
# Germany                   9042
# France                    8408
# EIRE                      7894
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1967
# Portugal                  1501
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Unspecified                446
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Hong Kong                  284
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              25
# Bahrain                     18
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %%
myretaildata.shape
# Out:
# (532326, 8)

# %%
myretaildata.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
# Verify missing value
myretaildata.isnull().sum().sort_values(ascending=False)
# Out:
# CustomerID     134650
# Description      1455
# InvoiceNo           0
# StockCode           0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# Country             0
# dtype: int64

# %%
myretaildata.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  532326.000000  532326.000000  397676.000000
# mean       10.237364       3.847741   15295.959361
# std       159.637302      41.769099    1712.437293
# min     -9600.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13969.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        10.000000       4.130000   16800.000000
# max     80995.000000   13541.330000   18287.000000

# %%
# Separating transactions for Italy only
mybasket = (myretaildata[myretaildata['Country'] =="Italy"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
# Viewing transaction basket
mybasket.head()
# Out:
# Description  12 EGG HOUSE PAINTED WOOD  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 537022                             0.0                                 0.0
# 539752                             0.0                                 0.0
# 541115                             0.0                                 0.0
# 541703                             0.0                                 0.0
# 542238                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE SKULLS  12 PENCILS TALL TUBE WOODLAND  \
# InvoiceNo
# 537022                               0.0                            0.0
# 539752                               0.0                            0.0
# 541115                               0.0                            0.0
# 541703                               0.0                            0.0
# 542238                               0.0                            0.0
#
# Description  16 PIECE CUTLERY SET PANTRY DESIGN  20 DOLLY PEGS RETROSPOT  \
# InvoiceNo
# 537022                                      0.0                      0.0
# 539752                                      0.0                      0.0
# 541115                                      0.0                      0.0
# 541703                                      0.0                      0.0
# 542238                                      0.0                      0.0
#
# Description  3 GARDENIA MORRIS BOXED CANDLES  3 ROSE MORRIS BOXED CANDLES  \
# InvoiceNo
# 537022                                   4.0                          4.0
# 539752                                   0.0                          0.0
# 541115                                   0.0                          0.0
# 541703                                   0.0                          0.0
# 542238                                   0.0                          0.0
#
# Description  3 STRIPEY MICE FELTCRAFT  3 TIER CAKE TIN RED AND CREAM  ...  \
# InvoiceNo                                                             ...
# 537022                            0.0                            0.0  ...
# 539752                            0.0                            0.0  ...
# 541115                            0.0                            0.0  ...
# 541703                            0.0                            0.0  ...
# 542238                            0.0                            0.0  ...
#
# Description  WOODLAND BUNNIES LOLLY MAKERS  WOODLAND CHARLOTTE BAG  \
# InvoiceNo
# 537022                                 0.0                     0.0
# 539752                                 0.0                     0.0
# 541115                                 0.0                     0.0
# 541703                                 0.0                     0.0
# 542238                                 0.0                     0.0
#
# Description  WRAP DOILEY DESIGN  WRAP ENGLISH ROSE  WRAP I LOVE LONDON  \
# InvoiceNo
# 537022                      0.0                0.0                 0.0
# 539752                      0.0                0.0                 0.0
# 541115                      0.0                0.0                 0.0
# 541703                      0.0                0.0                 0.0
# 542238                      0.0                0.0                 0.0
#
# Description  WRAP RED APPLES  WRAP RED VINTAGE DOILY  \
# InvoiceNo
# 537022                   0.0                     0.0
# 539752                   0.0                     0.0
# 541115                   0.0                     0.0
# 541703                   0.0                     0.0
# 542238                   0.0                     0.0
#
# Description  YOU'RE CONFUSING ME METAL SIGN  ZINC BOX SIGN HOME  \
# InvoiceNo
# 537022                                  0.0                 0.0
# 539752                                  0.0                 0.0
# 541115                                  0.0                 0.0
# 541703                                  0.0                 0.0
# 542238                                  0.0                 0.0
#
# Description  ZINC FOLKART SLEIGH BELLS
# InvoiceNo
# 537022                             0.0
# 539752                             0.0
# 541115                             0.0
# 541703                             0.0
# 542238                             0.0
#
# [5 rows x 476 columns]

# %%
# converting all positive values to 1(True) and everything else to 0(False) to get a formal table
def my_encode_units(x):
    if x <= 0:
        return False
    if x >= 1:
        return True

my_basket_sets = mybasket.applymap(my_encode_units)

# %%
# Viewing transaction basket
my_basket_sets.head()
# Out:
# Description  12 EGG HOUSE PAINTED WOOD  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 537022                           False                               False
# 539752                           False                               False
# 541115                           False                               False
# 541703                           False                               False
# 542238                           False                               False
#
# Description  12 PENCILS TALL TUBE SKULLS  12 PENCILS TALL TUBE WOODLAND  \
# InvoiceNo
# 537022                             False                          False
# 539752                             False                          False
# 541115                             False                          False
# 541703                             False                          False
# 542238                             False                          False
#
# Description  16 PIECE CUTLERY SET PANTRY DESIGN  20 DOLLY PEGS RETROSPOT  \
# InvoiceNo
# 537022                                    False                    False
# 539752                                    False                    False
# 541115                                    False                    False
# 541703                                    False                    False
# 542238                                    False                    False
#
# Description  3 GARDENIA MORRIS BOXED CANDLES  3 ROSE MORRIS BOXED CANDLES  \
# InvoiceNo
# 537022                                  True                         True
# 539752                                 False                        False
# 541115                                 False                        False
# 541703                                 False                        False
# 542238                                 False                        False
#
# Description  3 STRIPEY MICE FELTCRAFT  3 TIER CAKE TIN RED AND CREAM  ...  \
# InvoiceNo                                                             ...
# 537022                          False                          False  ...
# 539752                          False                          False  ...
# 541115                          False                          False  ...
# 541703                          False                          False  ...
# 542238                          False                          False  ...
#
# Description  WOODLAND BUNNIES LOLLY MAKERS  WOODLAND CHARLOTTE BAG  \
# InvoiceNo
# 537022                               False                   False
# 539752                               False                   False
# 541115                               False                   False
# 541703                               False                   False
# 542238                               False                   False
#
# Description  WRAP DOILEY DESIGN  WRAP ENGLISH ROSE  WRAP I LOVE LONDON  \
# InvoiceNo
# 537022                    False              False               False
# 539752                    False              False               False
# 541115                    False              False               False
# 541703                    False              False               False
# 542238                    False              False               False
#
# Description  WRAP RED APPLES  WRAP RED VINTAGE DOILY  \
# InvoiceNo
# 537022                 False                   False
# 539752                 False                   False
# 541115                 False                   False
# 541703                 False                   False
# 542238                 False                   False
#
# Description  YOU'RE CONFUSING ME METAL SIGN  ZINC BOX SIGN HOME  \
# InvoiceNo
# 537022                                False               False
# 539752                                False               False
# 541115                                False               False
# 541703                                False               False
# 542238                                False               False
#
# Description  ZINC FOLKART SLEIGH BELLS
# InvoiceNo
# 537022                           False
# 539752                           False
# 541115                           False
# 541703                           False
# 542238                           False
#
# [5 rows x 476 columns]

# %% [markdown]
# ## Training Model - Which items are frequently bought together?

# %%
# Generatig frequent itemsets
my_frequent_itemsets = apriori(my_basket_sets, min_support=0.07, use_colnames=True)

# %%
my_frequent_itemsets.head()
# Out:
#     support                        itemsets
# 0  0.105263         (ABC TREASURE BOOK BOX)
# 1  0.078947     (ADULT APRON APPLE DELIGHT)
# 2  0.105263  (BAKING SET 9 PIECE RETROSPOT)
# 3  0.157895   (BREAD BIN DINER STYLE IVORY)
# 4  0.078947    (BREAD BIN DINER STYLE PINK)

# %%
# Generating association rules
my_rules = association_rules(my_frequent_itemsets, metric="confidence", min_threshold=0.5)

# %%
# Viewing top 10 rules
my_rules.head(10)
# Out:
#                      antecedents                    consequents  \
# 0  (RED RETROSPOT CHARLOTTE BAG)        (ABC TREASURE BOOK BOX)
# 1        (ABC TREASURE BOOK BOX)  (RED RETROSPOT CHARLOTTE BAG)
# 2       (WOODLAND CHARLOTTE BAG)        (ABC TREASURE BOOK BOX)
# 3        (ABC TREASURE BOOK BOX)       (WOODLAND CHARLOTTE BAG)
# 4  (BREAD BIN DINER STYLE IVORY)           (DOORMAT UNION FLAG)
# 5           (DOORMAT UNION FLAG)  (BREAD BIN DINER STYLE IVORY)
# 6  (BREAD BIN DINER STYLE IVORY)     (JAM MAKING SET WITH JARS)
# 7     (JAM MAKING SET WITH JARS)  (BREAD BIN DINER STYLE IVORY)
# 8  (BREAD BIN DINER STYLE IVORY)          (MINT KITCHEN SCALES)
# 9          (MINT KITCHEN SCALES)  (BREAD BIN DINER STYLE IVORY)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.078947            0.105263  0.078947    1.000000  9.500000
# 1            0.105263            0.078947  0.078947    0.750000  9.500000
# 2            0.078947            0.105263  0.078947    1.000000  9.500000
# 3            0.105263            0.078947  0.078947    0.750000  9.500000
# 4            0.157895            0.157895  0.105263    0.666667  4.222222
# 5            0.157895            0.157895  0.105263    0.666667  4.222222
# 6            0.157895            0.184211  0.105263    0.666667  3.619048
# 7            0.184211            0.157895  0.105263    0.571429  3.619048
# 8            0.157895            0.131579  0.078947    0.500000  3.800000
# 9            0.131579            0.157895  0.078947    0.600000  3.800000
#
#    leverage  conviction
# 0  0.070637         inf
# 1  0.070637    3.684211
# 2  0.070637         inf
# 3  0.070637    3.684211
# 4  0.080332    2.526316
# 5  0.080332    2.526316
# 6  0.076177    2.447368
# 7  0.076177    1.964912
# 8  0.058172    1.736842
# 9  0.058172    2.105263

# %% [markdown]
# - support(A->C) = support(A+C) [aka 'support'], range: [0, 1]
#
# - confidence(A->C) = support(A+C) / support(A), range: [0, 1]
#
# - lift(A->C) = confidence(A->C) / support(C), range: [0, inf]
#
# - leverage(A->C) = support(A->C) - support(A)*support(C),
# range: [-1, 1]
#
# - conviction = [1 - support(C)] / [1 - confidence(A->C)],
# range: [0, inf]

# %%
# Filtering rules based on condition
my_rules[(my_rules['lift'] >= 5) & (my_rules['confidence'] >= 0.8)]
# Out:
#                                             antecedents  \
# 0                         (RED RETROSPOT CHARLOTTE BAG)
# 2                              (WOODLAND CHARLOTTE BAG)
# 23                                     (JUMBO BAG TOYS)
# 36                      (SET OF 20 KIDS COOKIE CUTTERS)
# 38                             (TOY TIDY PINK POLKADOT)
# ...                                                 ...
# 1317           (JUMBO BAG TOYS, TOY TIDY PINK POLKADOT)
# 1318  (JUMBO BAG WOODLAND ANIMALS, CHILDRENS APRON A...
# 1319    (TOY TIDY SPACEBOY, JUMBO BAG WOODLAND ANIMALS)
# 1320  (TOY TIDY PINK POLKADOT, JUMBO BAG WOODLAND AN...
# 1325                                   (JUMBO BAG TOYS)
#
#                                             consequents  antecedent support  \
# 0                               (ABC TREASURE BOOK BOX)            0.078947
# 2                               (ABC TREASURE BOOK BOX)            0.078947
# 23                      (CHILDRENS APRON APPLES DESIGN)            0.078947
# 36                      (CHILDRENS APRON APPLES DESIGN)            0.131579
# 38                      (CHILDRENS APRON APPLES DESIGN)            0.131579
# ...                                                 ...                 ...
# 1317  (RECYCLING BAG RETROSPOT, TOY TIDY SPACEBOY, J...            0.078947
# 1318  (RECYCLING BAG RETROSPOT, JUMBO BAG TOYS, TOY ...            0.078947
# 1319  (RECYCLING BAG RETROSPOT, JUMBO BAG TOYS, TOY ...            0.078947
# 1320  (RECYCLING BAG RETROSPOT, JUMBO BAG TOYS, TOY ...            0.078947
# 1325  (RECYCLING BAG RETROSPOT, JUMBO BAG WOODLAND A...            0.078947
#
#       consequent support   support  confidence       lift  leverage  \
# 0               0.105263  0.078947         1.0   9.500000  0.070637
# 2               0.105263  0.078947         1.0   9.500000  0.070637
# 23              0.157895  0.078947         1.0   6.333333  0.066482
# 36              0.157895  0.105263         0.8   5.066667  0.084488
# 38              0.157895  0.105263         0.8   5.066667  0.084488
# ...                  ...       ...         ...        ...       ...
# 1317            0.078947  0.078947         1.0  12.666667  0.072715
# 1318            0.078947  0.078947         1.0  12.666667  0.072715
# 1319            0.078947  0.078947         1.0  12.666667  0.072715
# 1320            0.078947  0.078947         1.0  12.666667  0.072715
# 1325            0.078947  0.078947         1.0  12.666667  0.072715
#
#       conviction
# 0            inf
# 2            inf
# 23           inf
# 36      4.210526
# 38      4.210526
# ...          ...
# 1317         inf
# 1318         inf
# 1319         inf
# 1320         inf
# 1325         inf
#
# [668 rows x 9 columns]

# %% [markdown]
# ### Make Recommendation

# %%
# Function in which we pass an item name, and it returns the items that are frequently bought together
def frequently_bought_t(item):
    # df of item passed
    item_d = my_basket_sets.loc[my_basket_sets[item]==True]
    # Applying apriori algorithm on item df
    frequentitemsets = apriori(item_d, min_support=0.8, use_colnames=True)
    # Storing association rules
    rules = association_rules(frequentitemsets, metric="confidence", min_threshold=0.7)
    # Sorting on confidence 
    rules.sort_values(['confidence'], ascending=False).reset_index(drop=True)
    print(f'Items frequently bought together with {item} : ')
    # Returning top 6 items with highest confidence
    return rules['consequents'].unique()[:6]

# %%
frequently_bought_t('JUMBO BAG TOYS')
# Out:
# Items frequently bought together with JUMBO BAG TOYS
# array([frozenset({'CHILDRENS APRON APPLES DESIGN'}),
#        frozenset({'JUMBO BAG TOYS'}),
#        frozenset({'JUMBO BAG WOODLAND ANIMALS'}),
#        frozenset({'RECYCLING BAG RETROSPOT'}),
#        frozenset({'TOY TIDY PINK POLKADOT'}),
#        frozenset({'TOY TIDY SPACEBOY'})], dtype=object)
